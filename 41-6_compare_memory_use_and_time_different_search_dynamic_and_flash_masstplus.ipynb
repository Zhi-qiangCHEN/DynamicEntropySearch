# %%
from pathlib import Path
path_spec_data=Path.cwd().parent.parent/"spec_data"
path_benchmark_data=Path.cwd().parent.parent/"benchmark_for_masstplus"

path_spec_data.mkdir(parents=True, exist_ok=True)
path_benchmark_data.mkdir(parents=True, exist_ok=True)

# %%
# Collect the files
import re
import os
pattern_pos=r"spectra-charge_1_batch_\d+\.mgf"
pattern_neg=r"spectra-charge_-1_batch_\d+\.mgf"
files=os.listdir(Path.cwd().parent.parent/"spec_data/benchmark_spec")
batch_mgf_pos=[]
for file in files:
    if re.match(pattern_pos, file):
        pos_num=file[23:-4]
        batch_mgf_pos.append(pos_num)


batch_mgf_neg=[]
for file in files:
    if re.match(pattern_neg, file):
        neg_num=file[24:-4]
        batch_mgf_neg.append(neg_num)

print(batch_mgf_pos)
print(batch_mgf_neg)
# Out:
# ['29', '92', '68', '10', '91', '5', '67', '47', '14', '96']
# ['56', '32', '67', '70', '87', '98', '54', '75', '88', '21']

# %%
# Only record hybrid search

original_library_size = [1_000_000,]
    
query_size = 100

num_per_group=10_000_000
cache_list_threshold=1_000_000
ion_mode = [-1, 1]

steps=["build", "open_search", "neutral_loss_search", "hybrid_search"]


dynamic_search_types=[
    "fast_search",
    "fast_update",
    "convert_to_flash"
]
dynamic_script_path="19_dynamic_entropy_search_library_scale_hybrid_fast_update_mode_every_step.py"
flash_script_path="23_flash_entropy_search_library_scale_hybrid_every_step.py"

# %%
import subprocess
import pickle
import os
import time
import shutil
from typing import Union
import numpy as np
# from dynamic_entropy_search.dynamic_entropy_search import DynamicEntropySearch
from dynamic_entropy_search.convert_to_mgf import _write_spec


def run_usrbintime_by_arguments(
          arguments:list[str], 
          if_output:bool=False, 
          output_memory_file:Union[str,Path]=None, 
          output_time_file:Union[str, Path]=None):
    
    # arguments: script_path, str(charge), step
    command=["/usr/bin/time","-v","python"] + arguments

    if if_output: # Output to files as record
        with open(output_memory_file, "w") as f1, open(output_time_file, "w") as f2:
            subprocess.run(command, stderr=f1, stdout=f2, cwd=Path.cwd(), env=os.environ.copy())

    else: # Output is not needed
         
        subprocess.run(command, stderr=subprocess.DEVNULL, stdout=subprocess.DEVNULL, cwd=Path.cwd(), env=os.environ.copy())
        
    return

def perform_search_and_record_one_by_one(
          script_path:Path, 
          search_type:str,
          charge:int,
          library_size:int,
          step:str,
          query_spectra_list:list,
          num_per_group:int,
          cache_list_threshold:int,
          method:str,
          if_output:bool=True, 
          ):
    
    for i, spec in enumerate(query_spectra_list):
        # Generate temp query file to perform search one by one
        temp_query_spec=path_spec_data/f"benchmark_spec/query_spectra-charge_{charge}_temp.pkl"
        with open(temp_query_spec, "wb") as temp1:

            # Write temp query pickle file
            pickle.dump(spec, temp1)

        if search_type is not None:
            arguments=[script_path, str(charge), str(num_per_group), str(cache_list_threshold), temp_query_spec, step]
            output_memory_file=path_benchmark_data/f"{method}_{search_type}_{charge}_{library_size}_memory_usage_{step}_step_query_{i}.txt"
            output_time_file=path_benchmark_data/f"{method}_{search_type}_{charge}_{library_size}_compare_time_{step}_step_query_{i}.txt"
        elif search_type is None:
            arguments=[script_path, str(charge), temp_query_spec, step]
            output_memory_file=path_benchmark_data/f"{method}_{charge}_{library_size}_memory_usage_{step}_step_query_{i}.txt"
            output_time_file=path_benchmark_data/f"{method}_{charge}_{library_size}_compare_time_{step}_step_query_{i}.txt"
        # Perform search and record memory usage and time
        run_usrbintime_by_arguments(arguments=arguments, if_output=if_output, output_memory_file=output_memory_file, output_time_file=output_time_file)
    

    return


for library_size in original_library_size:
    file_num=library_size//1000000

    for charge in ion_mode:
        for step in steps:
            if step=="build":
                if charge==-1:
                    random_file=batch_mgf_neg
                elif charge==1:
                    random_file=batch_mgf_pos

                # random_for_use=np.random.choice(100, file_num, replace=False)
                random_for_use=np.random.choice(random_file, file_num, replace=False)

                spec_bin=path_spec_data/f"35_random_export_ms2/charge_{charge}/batch_{random_for_use[0]}.bin"
                reference_mgf=path_spec_data/f"benchmark_spec/spectra-charge_{charge}_batch_{random_for_use[0]}.mgf"
            
            elif step=="open_search" or step=="neutral_loss_search" or step=="hybrid_search":

                query_pkl=path_spec_data/f"benchmark_spec/query_spectra-charge_{charge}-number_100.pkl"
                query_spectra=pickle.loads(open(query_pkl, "rb").read())

            if step=="build":

                ### DynamicEntropySearch ###
                # Remove the old index
                path_comparison_dynamic_data=Path.cwd().parent.parent/f"comparison_data/dynamic/charge-{charge}"
                if path_comparison_dynamic_data.exists():
                    shutil.rmtree(path_comparison_dynamic_data)

                path_comparison_dynamic_data_backup=Path.cwd().parent.parent/f"comparison_data/dynamic-backup/charge-{charge}"
                if path_comparison_dynamic_data_backup.exists():
                    shutil.rmtree(path_comparison_dynamic_data_backup)

                arguments=[dynamic_script_path, str(charge), str(num_per_group), str(cache_list_threshold), spec_bin, step]
                
                run_usrbintime_by_arguments(arguments=arguments, if_output=False)
                
                path_comparison_dynamic_data_backup=Path.cwd().parent.parent/f"comparison_data/dynamic-backup/charge-{charge}"
                if not path_comparison_dynamic_data_backup.exists():
                    shutil.copytree(src=path_comparison_dynamic_data, dst=path_comparison_dynamic_data_backup)
                
                ### FlashEntropySearch ###
                # Remove the old index
                path_comparison_flash_data=Path.cwd().parent.parent/f"comparison_data/flash/charge-{charge}"
                if path_comparison_flash_data.exists():
                    shutil.rmtree(path_comparison_flash_data)

                arguments=[flash_script_path, str(charge), spec_bin, step]

                run_usrbintime_by_arguments(arguments=arguments, if_output=False)
                
                ### MASST+ ###
                # Remove the old index
                path_masstp=Path.cwd().parent/"library/MASSTplus/build/masst_plus/tools/"
                path_masstp_lib=path_masstp/f"library-{charge}/"
                    
                if step=="build" and path_masstp_lib.exists():
                    shutil.rmtree(path_masstp_lib)
                    
                if step=="build":
                    command_str=f"./load {reference_mgf} -l {path_masstp_lib}"
                   
                result=subprocess.run(
                        ["/usr/bin/time", "-v", "sh", "-c", command_str],
                        stderr=subprocess.DEVNULL,
                        stdout=subprocess.PIPE,
                        env=os.environ.copy(),
                        cwd=path_masstp,
                        text=True
                    )


                
            if step=="hybrid_search" or step=="open_search" or step=="neutral_loss_search":

                ### DynamicEntropySearch ###
                method="dynamic"
                for search_type in dynamic_search_types:
                    
                    if search_type=="fast_search":
                        perform_search_and_record_one_by_one(
                            script_path=dynamic_script_path,
                            search_type=search_type,
                            charge=charge,
                            library_size=library_size,
                            step=step,
                            query_spectra_list=query_spectra,
                            num_per_group=num_per_group,
                            cache_list_threshold=cache_list_threshold,
                            method=method,
                            if_output=True
                        )
                    
                    if search_type=="fast_update":
                        # Simulate the out-of-order block condition by setting is_sorted to False
                        dtype_block_info = np.dtype(
                                            [
                                                ("start_idx", np.uint64),  # The start index of the block.
                                                ("data_len", np.uint32),  # The length of data in the block.
                                                ("reserved_len", np.uint32),  # The reserved length of the block.
                                                ("is_sorted", bool),  # Whether the block is sorted or not
                                            ]
                                        )
                        path_comparison_dynamic_data=Path.cwd().parent.parent/f"comparison_data/dynamic/charge-{charge}"
                        dynamic_entropy_search=DynamicEntropySearch(path_data=path_comparison_dynamic_data, num_per_group=num_per_group, cache_list_threshold=cache_list_threshold)
                        dynamic_entropy_search.read()
                        group_num=len(dynamic_entropy_search.group_start)

                        for i in range(group_num):

                            block_ion_info=np.memmap(path_comparison_dynamic_data/f"{i}/block_ions_info.bin", dtype=dtype_block_info, mode="r+")
                            block_ion_info["is_sorted"].fill(False)
                            block_ion_info.flush()

                            block_nl_info=np.memmap(path_comparison_dynamic_data/f"{i}/block_nl_info.bin", dtype=dtype_block_info, mode="r+")
                            block_nl_info["is_sorted"].fill(False)
                            block_nl_info.flush()

                        perform_search_and_record_one_by_one(
                            script_path=dynamic_script_path,
                            search_type=search_type,
                            charge=charge,
                            library_size=library_size,
                            step=step,
                            query_spectra_list=query_spectra,
                            num_per_group=num_per_group,
                            cache_list_threshold=cache_list_threshold,
                            method=method,
                            if_output=True)

                    if search_type=="convert_to_flash":

                        # Manually convert dynamic index to flash index
                        path_comparison_dynamic_data=Path.cwd().parent.parent/f"comparison_data/dynamic/charge-{charge}"
                        dynamic_entropy_search=DynamicEntropySearch(path_data=path_comparison_dynamic_data, num_per_group=num_per_group, cache_list_threshold=cache_list_threshold)
                        dynamic_entropy_search.convert_to_fast_search()
                        dynamic_entropy_search.read()
                        group_num=len(dynamic_entropy_search.group_start)
                        for i in range(group_num):

                            inner_path=path_comparison_dynamic_data/f"{i}"
                            dynamic_entropy_search.entropy_search.path_data=inner_path
                            dynamic_entropy_search.entropy_search.read()
                            dynamic_entropy_search.convert_current_index_to_flash()

                        perform_search_and_record_one_by_one(
                            script_path=dynamic_script_path,
                            search_type=search_type,
                            charge=charge,
                            library_size=library_size,
                            step=step,
                            query_spectra_list=query_spectra,
                            num_per_group=num_per_group,
                            cache_list_threshold=cache_list_threshold,
                            method=method,
                            if_output=True
                        )

                shutil.rmtree(path_comparison_dynamic_data)
                shutil.copytree(src=path_comparison_dynamic_data_backup, dst=path_comparison_dynamic_data)
                
                ### FlashEntropySearch ###
                method="flash"
                perform_search_and_record_one_by_one(
                    script_path=flash_script_path,
                    search_type=None,
                    charge=charge,
                    library_size=library_size,
                    step=step,
                    query_spectra_list=query_spectra,
                    num_per_group=None,
                    cache_list_threshold=None,
                    method=method,
                    if_output=True
                )

                if step=="hybrid_search":
                    ### MASST+ ###
                    method="masstplus"
                    # Create single spectrum files
                    for i, spec in enumerate(query_spectra):
                        temp_spec_mgf=path_spec_data/f"benchmark_spec/temp_spec.mgf"
                        with open(path_spec_data/f"benchmark_spec/temp_spec.mgf", "w") as temp1:
                            #Create temp mgf
                            _write_spec(spec, spec["peaks"], temp1)

                        path_masstp=Path.cwd().parent/"library/MASSTplus/build/masst_plus/tools/"
                        path_masstp_lib=path_masstp/f"library-{charge}/"
                            
                        # arguments: file_to_use, step
                        command_str=f"./search {temp_spec_mgf} -a -x -l {path_masstp_lib} -p 0.02 -t 0.0"
                            
                        with open(path_benchmark_data / f"{method}_{charge}_{library_size}_memory_usage_{step}_step_query_{i}.txt", "w") as f1,\
                            open(path_benchmark_data / f"{method}_{charge}_{library_size}_compare_time_{step}_step_query_{i}.txt", "w") as f2:
                            start_time=time.time()
                            result=subprocess.run(
                                    ["/usr/bin/time", "-v", "sh", "-c", command_str],
                                    stderr=f1,
                                    stdout=subprocess.PIPE,
                                    env=os.environ.copy(),
                                    cwd=path_masstp,
                                    text=True
                                )
                            elapsed_time=time.time()-start_time
                            f2.write(str(elapsed_time))
# Out:
# Loading index...
# Index loaded. Load time: 976ms. Searching...
# Query spectrum 0
# Search complete. Search time: 6194 ms.
# Match time: 6189 ms.
# Calc time: 678 ms.
#
# Loading index...
# Index loaded. Load time: 299ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3031 ms.
# Match time: 3030 ms.
# Calc time: 251 ms.
#
# Loading index...
# Index loaded. Load time: 517ms. Searching...
# Query spectrum 0
# Search complete. Search time: 4394 ms.
# Match time: 4392 ms.
# Calc time: 404 ms.
#
# Loading index...
# Index loaded. Load time: 338ms. Searching...
# Query spectrum 0
# Search complete. Search time: 301 ms.
# Match time: 299 ms.
# Calc time: 163 ms.
#
# Loading index...
# Index loaded. Load time: 278ms. Searching...
# Query spectrum 0
# Search complete. Search time: 207 ms.
# Match time: 205 ms.
# Calc time: 163 ms.
#
# Loading index...
# Index loaded. Load time: 1215ms. Searching...
# Query spectrum 0
# Search complete. Search time: 4015 ms.
# Match time: 4005 ms.
# Calc time: 621 ms.
#
# Loading index...
# Index loaded. Load time: 440ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1050 ms.
# Match time: 1047 ms.
# Calc time: 373 ms.
#
# Loading index...
# Index loaded. Load time: 937ms. Searching...
# Query spectrum 0
# Search complete. Search time: 6234 ms.
# Match time: 6229 ms.
# Calc time: 691 ms.
#
# Loading index...
# Index loaded. Load time: 1546ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2745 ms.
# Match time: 2732 ms.
# Calc time: 680 ms.
#
# Loading index...
# Index loaded. Load time: 170ms. Searching...
# Query spectrum 0
# Search complete. Search time: 61 ms.
# Match time: 59 ms.
# Calc time: 48 ms.
#
# Loading index...
# Index loaded. Load time: 115ms. Searching...
# Query spectrum 0
# Search complete. Search time: 174 ms.
# Match time: 173 ms.
# Calc time: 68 ms.
#
# Loading index...
# Index loaded. Load time: 221ms. Searching...
# Query spectrum 0
# Search complete. Search time: 706 ms.
# Match time: 703 ms.
# Calc time: 159 ms.
#
# Loading index...
# Index loaded. Load time: 441ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2813 ms.
# Match time: 2811 ms.
# Calc time: 306 ms.
#
# Loading index...
# Index loaded. Load time: 942ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3926 ms.
# Match time: 3921 ms.
# Calc time: 595 ms.
#
# Loading index...
# Index loaded. Load time: 201ms. Searching...
# Query spectrum 0
# Search complete. Search time: 84 ms.
# Match time: 82 ms.
# Calc time: 71 ms.
#
# Loading index...
# Index loaded. Load time: 263ms. Searching...
# Query spectrum 0
# Search complete. Search time: 220 ms.
# Match time: 216 ms.
# Calc time: 142 ms.
#
# Loading index...
# Index loaded. Load time: 57ms. Searching...
# Query spectrum 0
# Search complete. Search time: 15 ms.
# Match time: 14 ms.
# Calc time: 12 ms.
#
# Loading index...
# Index loaded. Load time: 519ms. Searching...
# Query spectrum 0
# Search complete. Search time: 481 ms.
# Match time: 476 ms.
# Calc time: 351 ms.
#
# Loading index...
# Index loaded. Load time: 88ms. Searching...
# Query spectrum 0
# Search complete. Search time: 107 ms.
# Match time: 107 ms.
# Calc time: 100 ms.
#
# Loading index...
# Index loaded. Load time: 123ms. Searching...
# Query spectrum 0
# Search complete. Search time: 135 ms.
# Match time: 133 ms.
# Calc time: 57 ms.
#
# Loading index...
# Index loaded. Load time: 71ms. Searching...
# Query spectrum 0
# Search complete. Search time: 579 ms.
# Match time: 578 ms.
# Calc time: 74 ms.
#
# Loading index...
# Index loaded. Load time: 1358ms. Searching...
# Query spectrum 0
# Search complete. Search time: 5703 ms.
# Match time: 5696 ms.
# Calc time: 825 ms.
#
# Loading index...
# Index loaded. Load time: 198ms. Searching...
# Query spectrum 0
# Search complete. Search time: 258 ms.
# Match time: 256 ms.
# Calc time: 151 ms.
#
# Loading index...
# Index loaded. Load time: 107ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1519 ms.
# Match time: 1519 ms.
# Calc time: 118 ms.
#
# Loading index...
# Index loaded. Load time: 422ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3298 ms.
# Match time: 3294 ms.
# Calc time: 321 ms.
#
# Loading index...
# Index loaded. Load time: 598ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3128 ms.
# Match time: 3125 ms.
# Calc time: 508 ms.
#
# Loading index...
# Index loaded. Load time: 178ms. Searching...
# Query spectrum 0
# Search complete. Search time: 228 ms.
# Match time: 227 ms.
# Calc time: 135 ms.
#
# Loading index...
# Index loaded. Load time: 303ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2806 ms.
# Match time: 2804 ms.
# Calc time: 325 ms.
#
# Loading index...
# Index loaded. Load time: 77ms. Searching...
# Query spectrum 0
# Search complete. Search time: 24 ms.
# Match time: 23 ms.
# Calc time: 21 ms.
#
# Loading index...
# Index loaded. Load time: 213ms. Searching...
# Query spectrum 0
# Search complete. Search time: 239 ms.
# Match time: 237 ms.
# Calc time: 194 ms.
#
# Loading index...
# Index loaded. Load time: 740ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3405 ms.
# Match time: 3399 ms.
# Calc time: 407 ms.
#
# Loading index...
# Index loaded. Load time: 99ms. Searching...
# Query spectrum 0
# Search complete. Search time: 78 ms.
# Match time: 77 ms.
# Calc time: 73 ms.
#
# Loading index...
# Index loaded. Load time: 431ms. Searching...
# Query spectrum 0
# Search complete. Search time: 845 ms.
# Match time: 841 ms.
# Calc time: 256 ms.
#
# Loading index...
# Index loaded. Load time: 692ms. Searching...
# Query spectrum 0
# Search complete. Search time: 4078 ms.
# Match time: 4073 ms.
# Calc time: 459 ms.
#
# Loading index...
# Index loaded. Load time: 172ms. Searching...
# Query spectrum 0
# Search complete. Search time: 115 ms.
# Match time: 113 ms.
# Calc time: 105 ms.
#
# Loading index...
# Index loaded. Load time: 311ms. Searching...
# Query spectrum 0
# Search complete. Search time: 103 ms.
# Match time: 99 ms.
# Calc time: 81 ms.
#
# Loading index...
# Index loaded. Load time: 182ms. Searching...
# Query spectrum 0
# Search complete. Search time: 52 ms.
# Match time: 50 ms.
# Calc time: 47 ms.
#
# Loading index...
# Index loaded. Load time: 151ms. Searching...
# Query spectrum 0
# Search complete. Search time: 160 ms.
# Match time: 160 ms.
# Calc time: 81 ms.
#
# Loading index...
# Index loaded. Load time: 389ms. Searching...
# Query spectrum 0
# Search complete. Search time: 513 ms.
# Match time: 510 ms.
# Calc time: 268 ms.
#
# Loading index...
# Index loaded. Load time: 202ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1570 ms.
# Match time: 1569 ms.
# Calc time: 142 ms.
#
# Loading index...
# Index loaded. Load time: 62ms. Searching...
# Query spectrum 0
# Search complete. Search time: 111 ms.
# Match time: 111 ms.
# Calc time: 43 ms.
#
# Loading index...
# Index loaded. Load time: 494ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1942 ms.
# Match time: 1939 ms.
# Calc time: 346 ms.
#
# Loading index...
# Index loaded. Load time: 71ms. Searching...
# Query spectrum 0
# Search complete. Search time: 38 ms.
# Match time: 37 ms.
# Calc time: 32 ms.
#
# Loading index...
# Index loaded. Load time: 396ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2719 ms.
# Match time: 2717 ms.
# Calc time: 285 ms.
#
# Loading index...
# Index loaded. Load time: 183ms. Searching...
# Query spectrum 0
# Search complete. Search time: 350 ms.
# Match time: 349 ms.
# Calc time: 153 ms.
#
# Loading index...
# Index loaded. Load time: 37ms. Searching...
# Query spectrum 0
# Search complete. Search time: 26 ms.
# Match time: 26 ms.
# Calc time: 15 ms.
#
# Loading index...
# Index loaded. Load time: 228ms. Searching...
# Query spectrum 0
# Search complete. Search time: 149 ms.
# Match time: 146 ms.
# Calc time: 133 ms.
#
# Loading index...
# Index loaded. Load time: 356ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1695 ms.
# Match time: 1692 ms.
# Calc time: 205 ms.
#
# Loading index...
# Index loaded. Load time: 221ms. Searching...
# Query spectrum 0
# Search complete. Search time: 222 ms.
# Match time: 220 ms.
# Calc time: 91 ms.
#
# Loading index...
# Index loaded. Load time: 628ms. Searching...
# Query spectrum 0
# Search complete. Search time: 473 ms.
# Match time: 468 ms.
# Calc time: 292 ms.
#
# Loading index...
# Index loaded. Load time: 239ms. Searching...
# Query spectrum 0
# Search complete. Search time: 249 ms.
# Match time: 247 ms.
# Calc time: 203 ms.
#
# Loading index...
# Index loaded. Load time: 1259ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3545 ms.
# Match time: 3537 ms.
# Calc time: 717 ms.
#
# Loading index...
# Index loaded. Load time: 166ms. Searching...
# Query spectrum 0
# Search complete. Search time: 122 ms.
# Match time: 120 ms.
# Calc time: 107 ms.
#
# Loading index...
# Index loaded. Load time: 87ms. Searching...
# Query spectrum 0
# Search complete. Search time: 135 ms.
# Match time: 135 ms.
# Calc time: 64 ms.
#
# Loading index...
# Index loaded. Load time: 204ms. Searching...
# Query spectrum 0
# Search complete. Search time: 72 ms.
# Match time: 70 ms.
# Calc time: 60 ms.
#
# Loading index...
# Index loaded. Load time: 60ms. Searching...
# Query spectrum 0
# Search complete. Search time: 100 ms.
# Match time: 100 ms.
# Calc time: 64 ms.
#
# Loading index...
# Index loaded. Load time: 713ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3344 ms.
# Match time: 3340 ms.
# Calc time: 531 ms.
#
# Loading index...
# Index loaded. Load time: 201ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2998 ms.
# Match time: 2997 ms.
# Calc time: 208 ms.
#
# Loading index...
# Index loaded. Load time: 675ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3521 ms.
# Match time: 3517 ms.
# Calc time: 474 ms.
#
# Loading index...
# Index loaded. Load time: 446ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1727 ms.
# Match time: 1723 ms.
# Calc time: 231 ms.
#
# Loading index...
# Index loaded. Load time: 52ms. Searching...
# Query spectrum 0
# Search complete. Search time: 8 ms.
# Match time: 8 ms.
# Calc time: 7 ms.
#
# Loading index...
# Index loaded. Load time: 297ms. Searching...
# Query spectrum 0
# Search complete. Search time: 187 ms.
# Match time: 184 ms.
# Calc time: 161 ms.
#
# Loading index...
# Index loaded. Load time: 765ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3452 ms.
# Match time: 3448 ms.
# Calc time: 537 ms.
#
# Loading index...
# Index loaded. Load time: 1068ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2576 ms.
# Match time: 2569 ms.
# Calc time: 610 ms.
#
# Loading index...
# Index loaded. Load time: 159ms. Searching...
# Query spectrum 0
# Search complete. Search time: 151 ms.
# Match time: 150 ms.
# Calc time: 104 ms.
#
# Loading index...
# Index loaded. Load time: 375ms. Searching...
# Query spectrum 0
# Search complete. Search time: 543 ms.
# Match time: 541 ms.
# Calc time: 224 ms.
#
# Loading index...
# Index loaded. Load time: 190ms. Searching...
# Query spectrum 0
# Search complete. Search time: 118 ms.
# Match time: 117 ms.
# Calc time: 112 ms.
#
# Loading index...
# Index loaded. Load time: 517ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2960 ms.
# Match time: 2956 ms.
# Calc time: 276 ms.
#
# Loading index...
# Index loaded. Load time: 47ms. Searching...
# Query spectrum 0
# Search complete. Search time: 54 ms.
# Match time: 54 ms.
# Calc time: 25 ms.
#
# Loading index...
# Index loaded. Load time: 335ms. Searching...
# Query spectrum 0
# Search complete. Search time: 449 ms.
# Match time: 448 ms.
# Calc time: 295 ms.
#
# Loading index...
# Index loaded. Load time: 168ms. Searching...
# Query spectrum 0
# Search complete. Search time: 121 ms.
# Match time: 120 ms.
# Calc time: 90 ms.
#
# Loading index...
# Index loaded. Load time: 656ms. Searching...
# Query spectrum 0
# Search complete. Search time: 530 ms.
# Match time: 526 ms.
# Calc time: 290 ms.
#
# Loading index...
# Index loaded. Load time: 287ms. Searching...
# Query spectrum 0
# Search complete. Search time: 263 ms.
# Match time: 261 ms.
# Calc time: 208 ms.
#
# Loading index...
# Index loaded. Load time: 187ms. Searching...
# Query spectrum 0
# Search complete. Search time: 182 ms.
# Match time: 180 ms.
# Calc time: 154 ms.
#
# Loading index...
# Index loaded. Load time: 273ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3097 ms.
# Match time: 3096 ms.
# Calc time: 273 ms.
#
# Loading index...
# Index loaded. Load time: 237ms. Searching...
# Query spectrum 0
# Search complete. Search time: 171 ms.
# Match time: 168 ms.
# Calc time: 133 ms.
#
# Loading index...
# Index loaded. Load time: 132ms. Searching...
# Query spectrum 0
# Search complete. Search time: 144 ms.
# Match time: 143 ms.
# Calc time: 99 ms.
#
# Loading index...
# Index loaded. Load time: 152ms. Searching...
# Query spectrum 0
# Search complete. Search time: 91 ms.
# Match time: 89 ms.
# Calc time: 62 ms.
#
# Loading index...
# Index loaded. Load time: 64ms. Searching...
# Query spectrum 0
# Search complete. Search time: 47 ms.
# Match time: 46 ms.
# Calc time: 37 ms.
#
# Loading index...
# Index loaded. Load time: 112ms. Searching...
# Query spectrum 0
# Search complete. Search time: 34 ms.
# Match time: 34 ms.
# Calc time: 31 ms.
#
# Loading index...
# Index loaded. Load time: 292ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2814 ms.
# Match time: 2813 ms.
# Calc time: 215 ms.
#
# Loading index...
# Index loaded. Load time: 507ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3041 ms.
# Match time: 3039 ms.
# Calc time: 333 ms.
#
# Loading index...
# Index loaded. Load time: 669ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2258 ms.
# Match time: 2253 ms.
# Calc time: 355 ms.
#
# Loading index...
# Index loaded. Load time: 478ms. Searching...
# Query spectrum 0
# Search complete. Search time: 521 ms.
# Match time: 517 ms.
# Calc time: 342 ms.
#
# Loading index...
# Index loaded. Load time: 1413ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1747 ms.
# Match time: 1738 ms.
# Calc time: 644 ms.
#
# Loading index...
# Index loaded. Load time: 32ms. Searching...
# Query spectrum 0
# Search complete. Search time: 6 ms.
# Match time: 6 ms.
# Calc time: 6 ms.
#
# Loading index...
# Index loaded. Load time: 144ms. Searching...
# Query spectrum 0
# Search complete. Search time: 32 ms.
# Match time: 32 ms.
# Calc time: 25 ms.
#
# Loading index...
# Index loaded. Load time: 104ms. Searching...
# Query spectrum 0
# Search complete. Search time: 74 ms.
# Match time: 73 ms.
# Calc time: 55 ms.
#
# Loading index...
# Index loaded. Load time: 202ms. Searching...
# Query spectrum 0
# Search complete. Search time: 498 ms.
# Match time: 496 ms.
# Calc time: 122 ms.
#
# Loading index...
# Index loaded. Load time: 310ms. Searching...
# Query spectrum 0
# Search complete. Search time: 211 ms.
# Match time: 207 ms.
# Calc time: 114 ms.
#
# Loading index...
# Index loaded. Load time: 29ms. Searching...
# Query spectrum 0
# Search complete. Search time: 41 ms.
# Match time: 41 ms.
# Calc time: 20 ms.
#
# Loading index...
# Index loaded. Load time: 181ms. Searching...
# Query spectrum 0
# Search complete. Search time: 72 ms.
# Match time: 71 ms.
# Calc time: 52 ms.
#
# Loading index...
# Index loaded. Load time: 830ms. Searching...
# Query spectrum 0
# Search complete. Search time: 724 ms.
# Match time: 716 ms.
# Calc time: 437 ms.
#
# Loading index...
# Index loaded. Load time: 280ms. Searching...
# Query spectrum 0
# Search complete. Search time: 195 ms.
# Match time: 192 ms.
# Calc time: 164 ms.
#
# Loading index...
# Index loaded. Load time: 156ms. Searching...
# Query spectrum 0
# Search complete. Search time: 50 ms.
# Match time: 49 ms.
# Calc time: 46 ms.
#
# Loading index...
# Index loaded. Load time: 304ms. Searching...
# Query spectrum 0
# Search complete. Search time: 414 ms.
# Match time: 412 ms.
# Calc time: 197 ms.
#
# Loading index...
# Index loaded. Load time: 182ms. Searching...
# Query spectrum 0
# Search complete. Search time: 58 ms.
# Match time: 56 ms.
# Calc time: 48 ms.
#
# Loading index...
# Index loaded. Load time: 832ms. Searching...
# Query spectrum 0
# Search complete. Search time: 4744 ms.
# Match time: 4738 ms.
# Calc time: 452 ms.
#
# Loading index...
# Index loaded. Load time: 527ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3140 ms.
# Match time: 3137 ms.
# Calc time: 335 ms.
#
# Loading index...
# Index loaded. Load time: 51ms. Searching...
# Query spectrum 0
# Search complete. Search time: 15 ms.
# Match time: 14 ms.
# Calc time: 12 ms.
#
# Loading index...
# Index loaded. Load time: 440ms. Searching...
# Query spectrum 0
# Search complete. Search time: 370 ms.
# Match time: 367 ms.
# Calc time: 233 ms.
#
# Loading index...
# Index loaded. Load time: 3011ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3884 ms.
# Match time: 3861 ms.
# Calc time: 1318 ms.
#
# Loading index...
# Index loaded. Load time: 2907ms. Searching...
# Query spectrum 0
# Search complete. Search time: 8148 ms.
# Match time: 8129 ms.
# Calc time: 1121 ms.
#
# Loading index...
# Index loaded. Load time: 2039ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3929 ms.
# Match time: 3920 ms.
# Calc time: 775 ms.
#
# Loading index...
# Index loaded. Load time: 560ms. Searching...
# Query spectrum 0
# Search complete. Search time: 730 ms.
# Match time: 726 ms.
# Calc time: 331 ms.
#
# Loading index...
# Index loaded. Load time: 550ms. Searching...
# Query spectrum 0
# Search complete. Search time: 572 ms.
# Match time: 568 ms.
# Calc time: 400 ms.
#
# Loading index...
# Index loaded. Load time: 417ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1333 ms.
# Match time: 1331 ms.
# Calc time: 330 ms.
#
# Loading index...
# Index loaded. Load time: 2317ms. Searching...
# Query spectrum 0
# Search complete. Search time: 6640 ms.
# Match time: 6626 ms.
# Calc time: 1120 ms.
#
# Loading index...
# Index loaded. Load time: 569ms. Searching...
# Query spectrum 0
# Search complete. Search time: 287 ms.
# Match time: 280 ms.
# Calc time: 195 ms.
#
# Loading index...
# Index loaded. Load time: 5805ms. Searching...
# Query spectrum 0
# Search complete. Search time: 6559 ms.
# Match time: 6517 ms.
# Calc time: 2084 ms.
#
# Loading index...
# Index loaded. Load time: 2160ms. Searching...
# Query spectrum 0
# Search complete. Search time: 4011 ms.
# Match time: 4000 ms.
# Calc time: 715 ms.
#
# Loading index...
# Index loaded. Load time: 6120ms. Searching...
# Query spectrum 0
# Search complete. Search time: 11476 ms.
# Match time: 11436 ms.
# Calc time: 2407 ms.
#
# Loading index...
# Index loaded. Load time: 215ms. Searching...
# Query spectrum 0
# Search complete. Search time: 104 ms.
# Match time: 103 ms.
# Calc time: 68 ms.
#
# Loading index...
# Index loaded. Load time: 5639ms. Searching...
# Query spectrum 0
# Search complete. Search time: 6261 ms.
# Match time: 6227 ms.
# Calc time: 1459 ms.
#
# Loading index...
# Index loaded. Load time: 491ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2042 ms.
# Match time: 2040 ms.
# Calc time: 259 ms.
#
# Loading index...
# Index loaded. Load time: 1668ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3520 ms.
# Match time: 3510 ms.
# Calc time: 651 ms.
#
# Loading index...
# Index loaded. Load time: 825ms. Searching...
# Query spectrum 0
# Search complete. Search time: 5447 ms.
# Match time: 5443 ms.
# Calc time: 559 ms.
#
# Loading index...
# Index loaded. Load time: 2824ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3084 ms.
# Match time: 3065 ms.
# Calc time: 1147 ms.
#
# Loading index...
# Index loaded. Load time: 6772ms. Searching...
# Query spectrum 0
# Search complete. Search time: 4300 ms.
# Match time: 4229 ms.
# Calc time: 1587 ms.
#
# Loading index...
# Index loaded. Load time: 2016ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3317 ms.
# Match time: 3305 ms.
# Calc time: 821 ms.
#
# Loading index...
# Index loaded. Load time: 317ms. Searching...
# Query spectrum 0
# Search complete. Search time: 193 ms.
# Match time: 190 ms.
# Calc time: 156 ms.
#
# Loading index...
# Index loaded. Load time: 8118ms. Searching...
# Query spectrum 0
# Search complete. Search time: 6270 ms.
# Match time: 6182 ms.
# Calc time: 2548 ms.
#
# Loading index...
# Index loaded. Load time: 2539ms. Searching...
# Query spectrum 0
# Search complete. Search time: 8213 ms.
# Match time: 8200 ms.
# Calc time: 1120 ms.
#
# Loading index...
# Index loaded. Load time: 495ms. Searching...
# Query spectrum 0
# Search complete. Search time: 621 ms.
# Match time: 618 ms.
# Calc time: 170 ms.
#
# Loading index...
# Index loaded. Load time: 2195ms. Searching...
# Query spectrum 0
# Search complete. Search time: 9515 ms.
# Match time: 9503 ms.
# Calc time: 1072 ms.
#
# Loading index...
# Index loaded. Load time: 3515ms. Searching...
# Query spectrum 0
# Search complete. Search time: 8555 ms.
# Match time: 8530 ms.
# Calc time: 1274 ms.
#
# Loading index...
# Index loaded. Load time: 1127ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2917 ms.
# Match time: 2911 ms.
# Calc time: 621 ms.
#
# Loading index...
# Index loaded. Load time: 1637ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2556 ms.
# Match time: 2545 ms.
# Calc time: 675 ms.
#
# Loading index...
# Index loaded. Load time: 263ms. Searching...
# Query spectrum 0
# Search complete. Search time: 4339 ms.
# Match time: 4338 ms.
# Calc time: 287 ms.
#
# Loading index...
# Index loaded. Load time: 392ms. Searching...
# Query spectrum 0
# Search complete. Search time: 340 ms.
# Match time: 336 ms.
# Calc time: 272 ms.
#
# Loading index...
# Index loaded. Load time: 341ms. Searching...
# Query spectrum 0
# Search complete. Search time: 413 ms.
# Match time: 411 ms.
# Calc time: 284 ms.
#
# Loading index...
# Index loaded. Load time: 4388ms. Searching...
# Query spectrum 0
# Search complete. Search time: 5831 ms.
# Match time: 5799 ms.
# Calc time: 1525 ms.
#
# Loading index...
# Index loaded. Load time: 779ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1814 ms.
# Match time: 1809 ms.
# Calc time: 480 ms.
#
# Loading index...
# Index loaded. Load time: 2676ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3858 ms.
# Match time: 3836 ms.
# Calc time: 940 ms.
#
# Loading index...
# Index loaded. Load time: 386ms. Searching...
# Query spectrum 0
# Search complete. Search time: 202 ms.
# Match time: 199 ms.
# Calc time: 150 ms.
#
# Loading index...
# Index loaded. Load time: 905ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2551 ms.
# Match time: 2545 ms.
# Calc time: 437 ms.
#
# Loading index...
# Index loaded. Load time: 262ms. Searching...
# Query spectrum 0
# Search complete. Search time: 4248 ms.
# Match time: 4247 ms.
# Calc time: 275 ms.
#
# Loading index...
# Index loaded. Load time: 507ms. Searching...
# Query spectrum 0
# Search complete. Search time: 428 ms.
# Match time: 423 ms.
# Calc time: 182 ms.
#
# Loading index...
# Index loaded. Load time: 713ms. Searching...
# Query spectrum 0
# Search complete. Search time: 479 ms.
# Match time: 473 ms.
# Calc time: 215 ms.
#
# Loading index...
# Index loaded. Load time: 269ms. Searching...
# Query spectrum 0
# Search complete. Search time: 280 ms.
# Match time: 278 ms.
# Calc time: 127 ms.
#
# Loading index...
# Index loaded. Load time: 403ms. Searching...
# Query spectrum 0
# Search complete. Search time: 375 ms.
# Match time: 372 ms.
# Calc time: 211 ms.
#
# Loading index...
# Index loaded. Load time: 311ms. Searching...
# Query spectrum 0
# Search complete. Search time: 242 ms.
# Match time: 239 ms.
# Calc time: 146 ms.
#
# Loading index...
# Index loaded. Load time: 2101ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3027 ms.
# Match time: 3013 ms.
# Calc time: 910 ms.
#
# Loading index...
# Index loaded. Load time: 729ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1926 ms.
# Match time: 1924 ms.
# Calc time: 369 ms.
#
# Loading index...
# Index loaded. Load time: 1375ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1917 ms.
# Match time: 1909 ms.
# Calc time: 856 ms.
#
# Loading index...
# Index loaded. Load time: 703ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2212 ms.
# Match time: 2209 ms.
# Calc time: 304 ms.
#
# Loading index...
# Index loaded. Load time: 1451ms. Searching...
# Query spectrum 0
# Search complete. Search time: 4000 ms.
# Match time: 3991 ms.
# Calc time: 696 ms.
#
# Loading index...
# Index loaded. Load time: 5510ms. Searching...
# Query spectrum 0
# Search complete. Search time: 12651 ms.
# Match time: 12616 ms.
# Calc time: 1871 ms.
#
# Loading index...
# Index loaded. Load time: 2361ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2333 ms.
# Match time: 2320 ms.
# Calc time: 968 ms.
#
# Loading index...
# Index loaded. Load time: 1138ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3362 ms.
# Match time: 3357 ms.
# Calc time: 669 ms.
#
# Loading index...
# Index loaded. Load time: 709ms. Searching...
# Query spectrum 0
# Search complete. Search time: 990 ms.
# Match time: 985 ms.
# Calc time: 330 ms.
#
# Loading index...
# Index loaded. Load time: 211ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1018 ms.
# Match time: 1017 ms.
# Calc time: 184 ms.
#
# Loading index...
# Index loaded. Load time: 3781ms. Searching...
# Query spectrum 0
# Search complete. Search time: 4456 ms.
# Match time: 4426 ms.
# Calc time: 1323 ms.
#
# Loading index...
# Index loaded. Load time: 940ms. Searching...
# Query spectrum 0
# Search complete. Search time: 574 ms.
# Match time: 567 ms.
# Calc time: 340 ms.
#
# Loading index...
# Index loaded. Load time: 531ms. Searching...
# Query spectrum 0
# Search complete. Search time: 324 ms.
# Match time: 320 ms.
# Calc time: 209 ms.
#
# Loading index...
# Index loaded. Load time: 70ms. Searching...
# Query spectrum 0
# Search complete. Search time: 18 ms.
# Match time: 17 ms.
# Calc time: 16 ms.
#
# Loading index...
# Index loaded. Load time: 434ms. Searching...
# Query spectrum 0
# Search complete. Search time: 199 ms.
# Match time: 195 ms.
# Calc time: 121 ms.
#
# Loading index...
# Index loaded. Load time: 5652ms. Searching...
# Query spectrum 0
# Search complete. Search time: 10344 ms.
# Match time: 10303 ms.
# Calc time: 2208 ms.
#
# Loading index...
# Index loaded. Load time: 1030ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1885 ms.
# Match time: 1880 ms.
# Calc time: 422 ms.
#
# Loading index...
# Index loaded. Load time: 3291ms. Searching...
# Query spectrum 0
# Search complete. Search time: 4883 ms.
# Match time: 4865 ms.
# Calc time: 1235 ms.
#
# Loading index...
# Index loaded. Load time: 591ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1167 ms.
# Match time: 1164 ms.
# Calc time: 261 ms.
#
# Loading index...
# Index loaded. Load time: 2364ms. Searching...
# Query spectrum 0
# Search complete. Search time: 7570 ms.
# Match time: 7550 ms.
# Calc time: 1105 ms.
#
# Loading index...
# Index loaded. Load time: 196ms. Searching...
# Query spectrum 0
# Search complete. Search time: 73 ms.
# Match time: 71 ms.
# Calc time: 57 ms.
#
# Loading index...
# Index loaded. Load time: 538ms. Searching...
# Query spectrum 0
# Search complete. Search time: 496 ms.
# Match time: 491 ms.
# Calc time: 344 ms.
#
# Loading index...
# Index loaded. Load time: 822ms. Searching...
# Query spectrum 0
# Search complete. Search time: 5726 ms.
# Match time: 5722 ms.
# Calc time: 547 ms.
#
# Loading index...
# Index loaded. Load time: 317ms. Searching...
# Query spectrum 0
# Search complete. Search time: 298 ms.
# Match time: 295 ms.
# Calc time: 200 ms.
#
# Loading index...
# Index loaded. Load time: 515ms. Searching...
# Query spectrum 0
# Search complete. Search time: 464 ms.
# Match time: 459 ms.
# Calc time: 321 ms.
#
# Loading index...
# Index loaded. Load time: 1465ms. Searching...
# Query spectrum 0
# Search complete. Search time: 772 ms.
# Match time: 763 ms.
# Calc time: 488 ms.
#
# Loading index...
# Index loaded. Load time: 2349ms. Searching...
# Query spectrum 0
# Search complete. Search time: 6476 ms.
# Match time: 6458 ms.
# Calc time: 828 ms.
#
# Loading index...
# Index loaded. Load time: 1318ms. Searching...
# Query spectrum 0
# Search complete. Search time: 7669 ms.
# Match time: 7662 ms.
# Calc time: 743 ms.
#
# Loading index...
# Index loaded. Load time: 1926ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1842 ms.
# Match time: 1828 ms.
# Calc time: 845 ms.
#
# Loading index...
# Index loaded. Load time: 2822ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3940 ms.
# Match time: 3921 ms.
# Calc time: 1297 ms.
#
# Loading index...
# Index loaded. Load time: 71ms. Searching...
# Query spectrum 0
# Search complete. Search time: 45 ms.
# Match time: 45 ms.
# Calc time: 31 ms.
#
# Loading index...
# Index loaded. Load time: 1035ms. Searching...
# Query spectrum 0
# Search complete. Search time: 676 ms.
# Match time: 669 ms.
# Calc time: 408 ms.
#
# Loading index...
# Index loaded. Load time: 2369ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1906 ms.
# Match time: 1888 ms.
# Calc time: 916 ms.
#
# Loading index...
# Index loaded. Load time: 1388ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2604 ms.
# Match time: 2594 ms.
# Calc time: 595 ms.
#
# Loading index...
# Index loaded. Load time: 257ms. Searching...
# Query spectrum 0
# Search complete. Search time: 147 ms.
# Match time: 145 ms.
# Calc time: 92 ms.
#
# Loading index...
# Index loaded. Load time: 2153ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2950 ms.
# Match time: 2934 ms.
# Calc time: 968 ms.
#
# Loading index...
# Index loaded. Load time: 672ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1662 ms.
# Match time: 1658 ms.
# Calc time: 401 ms.
#
# Loading index...
# Index loaded. Load time: 472ms. Searching...
# Query spectrum 0
# Search complete. Search time: 605 ms.
# Match time: 603 ms.
# Calc time: 318 ms.
#
# Loading index...
# Index loaded. Load time: 391ms. Searching...
# Query spectrum 0
# Search complete. Search time: 4215 ms.
# Match time: 4212 ms.
# Calc time: 260 ms.
#
# Loading index...
# Index loaded. Load time: 1648ms. Searching...
# Query spectrum 0
# Search complete. Search time: 6982 ms.
# Match time: 6970 ms.
# Calc time: 765 ms.
#
# Loading index...
# Index loaded. Load time: 919ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2645 ms.
# Match time: 2639 ms.
# Calc time: 446 ms.
#
# Loading index...
# Index loaded. Load time: 3405ms. Searching...
# Query spectrum 0
# Search complete. Search time: 3029 ms.
# Match time: 3009 ms.
# Calc time: 1170 ms.
#
# Loading index...
# Index loaded. Load time: 507ms. Searching...
# Query spectrum 0
# Search complete. Search time: 513 ms.
# Match time: 509 ms.
# Calc time: 187 ms.
#
# Loading index...
# Index loaded. Load time: 397ms. Searching...
# Query spectrum 0
# Search complete. Search time: 344 ms.
# Match time: 340 ms.
# Calc time: 253 ms.
#
# Loading index...
# Index loaded. Load time: 1532ms. Searching...
# Query spectrum 0
# Search complete. Search time: 5824 ms.
# Match time: 5817 ms.
# Calc time: 715 ms.
#
# Loading index...
# Index loaded. Load time: 326ms. Searching...
# Query spectrum 0
# Search complete. Search time: 338 ms.
# Match time: 337 ms.
# Calc time: 202 ms.
#
# Loading index...
# Index loaded. Load time: 454ms. Searching...
# Query spectrum 0
# Search complete. Search time: 370 ms.
# Match time: 366 ms.
# Calc time: 301 ms.
#
# Loading index...
# Index loaded. Load time: 599ms. Searching...
# Query spectrum 0
# Search complete. Search time: 573 ms.
# Match time: 568 ms.
# Calc time: 331 ms.
#
# Loading index...
# Index loaded. Load time: 560ms. Searching...
# Query spectrum 0
# Search complete. Search time: 4443 ms.
# Match time: 4440 ms.
# Calc time: 377 ms.
#
# Loading index...
# Index loaded. Load time: 506ms. Searching...
# Query spectrum 0
# Search complete. Search time: 276 ms.
# Match time: 274 ms.
# Calc time: 204 ms.
#
# Loading index...
# Index loaded. Load time: 131ms. Searching...
# Query spectrum 0
# Search complete. Search time: 162 ms.
# Match time: 161 ms.
# Calc time: 64 ms.
#
# Loading index...
# Index loaded. Load time: 1189ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2791 ms.
# Match time: 2783 ms.
# Calc time: 644 ms.
#
# Loading index...
# Index loaded. Load time: 1425ms. Searching...
# Query spectrum 0
# Search complete. Search time: 6945 ms.
# Match time: 6939 ms.
# Calc time: 719 ms.
#
# Loading index...
# Index loaded. Load time: 671ms. Searching...
# Query spectrum 0
# Search complete. Search time: 656 ms.
# Match time: 651 ms.
# Calc time: 445 ms.
#
# Loading index...
# Index loaded. Load time: 1574ms. Searching...
# Query spectrum 0
# Search complete. Search time: 1340 ms.
# Match time: 1330 ms.
# Calc time: 535 ms.
#
# Loading index...
# Index loaded. Load time: 337ms. Searching...
# Query spectrum 0
# Search complete. Search time: 222 ms.
# Match time: 220 ms.
# Calc time: 103 ms.
#
# Loading index...
# Index loaded. Load time: 3710ms. Searching...
# Query spectrum 0
# Search complete. Search time: 2282 ms.
# Match time: 2239 ms.
# Calc time: 1022 ms.
#
# Loading index...
# Index loaded. Load time: 55ms. Searching...
# Query spectrum 0
# Search complete. Search time: 34 ms.
# Match time: 33 ms.
# Calc time: 20 ms.
